# %%
import pandas as pd

# %%
df1=pd.read_csv('Access_to_Electricity_%_of_population.csv')
df2 = pd.read_csv('CO2_Emissions_metric_tons_per_capita.csv')
df3 = pd.read_csv('Forest_Area_%_of_land_area.csv')
df4 = pd.read_csv('Renewable_Energy_Consumption_%_of_total_final_energy_consumption.csv')

# %%
df1
# Out:
#    countryiso3code  date      value  unit  obs_status  decimal  \
# 0              KEN  2023        NaN   NaN         NaN        1
# 1              KEN  2022        NaN   NaN         NaN        1
# 2              KEN  2021  76.542450   NaN         NaN        1
# 3              KEN  2020  71.492714   NaN         NaN        1
# 4              KEN  2019  69.700000   NaN         NaN        1
# ..             ...   ...        ...   ...         ...      ...
# 59             KEN  1964        NaN   NaN         NaN        1
# 60             KEN  1963        NaN   NaN         NaN        1
# 61             KEN  1962        NaN   NaN         NaN        1
# 62             KEN  1961        NaN   NaN         NaN        1
# 63             KEN  1960        NaN   NaN         NaN        1
#
#       indicator.id                          indicator.value country.id  \
# 0   EG.ELC.ACCS.ZS  Access to electricity (% of population)         KE
# ...

# %%
df2
# Out:
#    countryiso3code  date     value  unit  obs_status  decimal    indicator.id  \
# 0              KEN  2023       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 1              KEN  2022       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 2              KEN  2021       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 3              KEN  2020  0.374079   NaN         NaN        1  EN.ATM.CO2E.PC
# 4              KEN  2019  0.382362   NaN         NaN        1  EN.ATM.CO2E.PC
# ..             ...   ...       ...   ...         ...      ...             ...
# 59             KEN  1964       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 60             KEN  1963       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 61             KEN  1962       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 62             KEN  1961       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 63             KEN  1960       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
#
# ...

# %%
df2
# Out:
#    countryiso3code  date     value  unit  obs_status  decimal    indicator.id  \
# 0              KEN  2023       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 1              KEN  2022       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 2              KEN  2021       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 3              KEN  2020  0.374079   NaN         NaN        1  EN.ATM.CO2E.PC
# 4              KEN  2019  0.382362   NaN         NaN        1  EN.ATM.CO2E.PC
# ..             ...   ...       ...   ...         ...      ...             ...
# 59             KEN  1964       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 60             KEN  1963       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 61             KEN  1962       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 62             KEN  1961       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
# 63             KEN  1960       NaN   NaN         NaN        1  EN.ATM.CO2E.PC
#
# ...

# %%
df3
# Out:
#    countryiso3code  date     value  unit  obs_status  decimal    indicator.id  \
# 0              KEN  2023       NaN   NaN         NaN        1  AG.LND.FRST.ZS
# 1              KEN  2022       NaN   NaN         NaN        1  AG.LND.FRST.ZS
# 2              KEN  2021  6.344818   NaN         NaN        1  AG.LND.FRST.ZS
# 3              KEN  2020  6.344818   NaN         NaN        1  AG.LND.FRST.ZS
# 4              KEN  2019  6.344818   NaN         NaN        1  AG.LND.FRST.ZS
# ..             ...   ...       ...   ...         ...      ...             ...
# 59             KEN  1964       NaN   NaN         NaN        1  AG.LND.FRST.ZS
# 60             KEN  1963       NaN   NaN         NaN        1  AG.LND.FRST.ZS
# 61             KEN  1962       NaN   NaN         NaN        1  AG.LND.FRST.ZS
# 62             KEN  1961       NaN   NaN         NaN        1  AG.LND.FRST.ZS
# 63             KEN  1960       NaN   NaN         NaN        1  AG.LND.FRST.ZS
#
# ...

# %%
df4
# Out:
#    countryiso3code  date  value  unit  obs_status  decimal    indicator.id  \
# 0              KEN  2023    NaN   NaN         NaN        2  EG.FEC.RNEW.ZS
# 1              KEN  2022    NaN   NaN         NaN        2  EG.FEC.RNEW.ZS
# 2              KEN  2021    NaN   NaN         NaN        2  EG.FEC.RNEW.ZS
# 3              KEN  2020  72.50   NaN         NaN        2  EG.FEC.RNEW.ZS
# 4              KEN  2019  71.42   NaN         NaN        2  EG.FEC.RNEW.ZS
# ..             ...   ...    ...   ...         ...      ...             ...
# 59             KEN  1964    NaN   NaN         NaN        2  EG.FEC.RNEW.ZS
# 60             KEN  1963    NaN   NaN         NaN        2  EG.FEC.RNEW.ZS
# 61             KEN  1962    NaN   NaN         NaN        2  EG.FEC.RNEW.ZS
# 62             KEN  1961    NaN   NaN         NaN        2  EG.FEC.RNEW.ZS
# 63             KEN  1960    NaN   NaN         NaN        2  EG.FEC.RNEW.ZS
#
# ...
